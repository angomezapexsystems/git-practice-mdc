# %%
import pyspark.sql.functions as F
from pyspark.sql import SparkSession
import os

# %%
master_url = os.environ.get("SPARK_MASTER", "spark://spark-master:7077")

spark = SparkSession.builder \
    .appName("test") \
    .master(master_url) \
    .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/04 21:09:33 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
path = "/opt/spark/data/test.csv"
df = spark.read.csv(path, header=True, inferSchema=True)

df.show()
# Out:
# +--------+---------------+
# |username|           name|
# +--------+---------------+
# |hmorales|Horacio Morales|
# | arreyes|      Ari Reyes|
# | mchenge|  Miguel Chenge|
# +--------+---------------+
